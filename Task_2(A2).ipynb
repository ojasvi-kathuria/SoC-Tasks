# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('Dataset.csv')

# %%
df.head()
# Out:
#    country  year  ... gdp_per_capita ($)       generation
# 0  Albania  1987  ...                796     Generation X
# 1  Albania  1987  ...                796           Silent
# 2  Albania  1987  ...                796     Generation X
# 3  Albania  1987  ...                796  G.I. Generation
# 4  Albania  1987  ...                796          Boomers
#
# [5 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year',
#        ' gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation'],
#       dtype='object')

# %%
my_list= ['country','sex', 'age', 'generation']
for col in my_list:
  df[col].hist()
  plt.show()

# %%
my_list= ['country','sex', 'age', 'generation']
df1 = df[my_list]
print(df1.mode().loc[0])
# Out:
# country            Austria
# sex                 female
# age            15-24 years
# generation    Generation X
# Name: 0, dtype: object

# %% [markdown]
# good number of bins

# %%
my_list2 =['year','suicides_no','population','suicides/100k pop', 'country-year','HDI for year', 'gdp_for_year ($)', 'gdp_per_capita ($)']
for col in my_list2:
  df[col].hist(bins=20)
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gdp_for_year ($)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-f43b205de0e7> in <module>()
#       1 my_list2 =['year','suicides_no','population','suicides/100k pop', 'country-year','HDI for year', 'gdp_for_year ($)', 'gdp_per_capita ($)']
#       2 for col in my_list2:
# ----> 3   df[col].hist(bins=20)
#       4   plt.show()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'gdp_for_year ($)'

# %% [markdown]
# too many bins

# %%
my_list2 =['year','suicides_no','population','suicides/100k pop', 'country-year','HDI for year', 'gdp_for_year', 'gdp_per_capita']
for col in my_list2:
  df[col].hist(bins=100)
  plt.show()

# %% [markdown]
# too few bins

# %%
my_list2 =['year','suicides_no','population','suicides/100k pop', 'country-year','HDI for year', 'gdp_for_year', 'gdp_per_capita']
for col in my_list2:
  df[col].hist(bins=3)
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gdp_for_year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-51f930d69462> in <module>()
#       1 my_list2 =['year','suicides_no','population','suicides/100k pop', 'country-year','HDI for year', 'gdp_for_year', 'gdp_per_capita']
#       2 for col in my_list2:
# ----> 3   df[col].hist(bins=3)
#       4   plt.show()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'gdp_for_year'

# %% [markdown]
# box plot

# %%
my_list3=['year','suicides_no','population','suicides/100k pop']

for col in my_list3:
  df[col].plot(kind='box')
  plt.show()

# %%
my_list2 =['year','suicides_no','population','suicides/100k pop', 'country-year','HDI for year',' gdp_for_year ($) ', 'gdp_per_capita ($)']
df3= df[my_list2]
k=df3.describe()

l1  = k.iloc[6]
l2 = k.iloc[4]

k.loc["IQR"] = l1-l2
print(k)
# Out:
#                year   suicides_no  ...  HDI for year  gdp_per_capita ($)
# count  27820.000000  27820.000000  ...   8364.000000        27820.000000
# mean    2001.258375    242.574407  ...      0.776601        16866.464414
# std        8.469055    902.047917  ...      0.093367        18887.576472
# min     1985.000000      0.000000  ...      0.483000          251.000000
# 25%     1995.000000      3.000000  ...      0.713000         3447.000000
# 50%     2002.000000     25.000000  ...      0.779000         9372.000000
# 75%     2008.000000    131.000000  ...      0.855000        24874.000000
# max     2016.000000  22338.000000  ...      0.944000       126352.000000
# IQR       13.000000    128.000000  ...      0.142000        21427.000000
#
# [9 rows x 6 columns]
